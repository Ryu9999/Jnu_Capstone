# %%
import librosa
import librosa.display
import IPython.display
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.font_manager as fm
import os
import csv
import pandas as pd

# %%
for filename in os.listdir(f'./mood/in'):
    songname = f'./mood/in/{filename}'
    y, sr = librosa.load(songname)
    print(np.mean(librosa.feature.mfcc(y=y, sr=sr)))
# Out:
# C:\anaconda\lib\site-packages\librosa\core\audio.py:161: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn('PySoundFile failed. Trying audioread instead.')
# 5.765547

# %%
a=librosa.feature.mfcc(y=y, sr=sr)[19]
np.mean(a)
# Out:
# -0.42948765

# %%
a=librosa.feature.chroma_stft(y=y, sr=sr)
c = a.mean(axis=1)

# %%
c

# %%
np.mean(librosa.feature.chroma_stft(y=y, sr=sr))

# %%
a.shape

# %%
count=1;
id=[]
songnames = []
tempo = []
chroma_stft_1 = []
chroma_stft_2 = []
chroma_stft_3 = []
chroma_stft_4 = []
chroma_stft_5 = []
chroma_stft_6 = []
chroma_stft_7 = []
chroma_stft_8 = []
chroma_stft_9 = []
chroma_stft_10 = []
chroma_stft_11 = []
chroma_stft_12 = []
rmse = []
spec_cent = []
spec_bw = []
spec_cont = []
spec_flat = []
rolloff = [] 
tonnetz_1 = []
tonnetz_2 = []
tonnetz_3 = []
tonnetz_4 = []
tonnetz_5 = []
tonnetz_6 = []
zcr = []
mfcc1 = []
mfcc2 = []
mfcc3 = []
mfcc4 = []
mfcc5 = []
mfcc6 = []
mfcc7 = []
mfcc8 = []
mfcc9 = []
mfcc10 = []
mfcc11 = []
mfcc12 = []
mfcc13 = []
mfcc14 = []
mfcc15 = []
mfcc16 = []
mfcc17 = []
mfcc18 = []
mfcc19 = []
mfcc20 = []
data={"id" : id
      ,"songname" : songnames
    ,"tempo":tempo
    ,"chroma_shft_1":chroma_stft_1
      ,"chroma_shft_2":chroma_stft_2
      ,"chroma_shft_3":chroma_stft_3
      ,"chroma_shft_4":chroma_stft_4
      ,"chroma_shft_5":chroma_stft_5
      ,"chroma_shft_6":chroma_stft_6
      ,"chroma_shft_7":chroma_stft_7
      ,"chroma_shft_8":chroma_stft_8
      ,"chroma_shft_9":chroma_stft_9
      ,"chroma_shft_10":chroma_stft_10
      ,"chroma_shft_11":chroma_stft_11
      ,"chroma_shft_12":chroma_stft_12
     ,"rmse" : rmse
     ,"spec_cent" : spec_cent
     ,"spec_bw" : spec_bw
     ,"spec_cont" : spec_cont
     ,"spec_flat" : spec_flat
     ,"rolloff" : rolloff
     ,"tonnetz_1" : tonnetz_1
    ,"tonnetz_2" : tonnetz_2
      ,"tonnetz_3" : tonnetz_3
      ,"tonnetz_4" : tonnetz_4
      ,"tonnetz_5" : tonnetz_5
      ,"tonnetz_6" : tonnetz_6
     ,"zcr" : zcr
     ,"mfcc1" : mfcc1
      ,"mfcc2" : mfcc2
      ,"mfcc3" : mfcc3
      ,"mfcc4" : mfcc4
      ,"mfcc5" : mfcc5
      ,"mfcc6" : mfcc6
      ,"mfcc7" : mfcc7
      ,"mfcc8" : mfcc8
      ,"mfcc9" : mfcc9
      ,"mfcc10" : mfcc10
      ,"mfcc11" : mfcc11
      ,"mfcc12" : mfcc12
      ,"mfcc13" : mfcc13
      ,"mfcc14" : mfcc14
      ,"mfcc15" : mfcc15
      ,"mfcc16" : mfcc16
      ,"mfcc17" : mfcc17
      ,"mfcc18" : mfcc18
      ,"mfcc19" : mfcc19
      ,"mfcc20" : mfcc20
     }
#Librosa를 통해 음악의 특징 추출
for filename in os.listdir(f'./DEAM_audio/MEMD_audio'):
        songname = f'./DEAM_audio/MEMD_audio/{filename}'
        print(songname)
        y, sr = librosa.load(songname)
        onset_env = librosa.onset.onset_strength(y, sr=sr)
        tempo1=librosa.beat.tempo(onset_envelope=onset_env, sr=sr)
        tempo.append(tempo1[0])
        chst=librosa.feature.chroma_stft(y=y, sr=sr)
        chroma_stft_1.append(np.mean(chst[0]))
        chroma_stft_2.append(np.mean(chst[1]))
        chroma_stft_3.append(np.mean(chst[2]))
        chroma_stft_4.append(np.mean(chst[3]))
        chroma_stft_5.append(np.mean(chst[4]))
        chroma_stft_6.append(np.mean(chst[5]))
        chroma_stft_7.append(np.mean(chst[6]))
        chroma_stft_8.append(np.mean(chst[7]))
        chroma_stft_9.append(np.mean(chst[8]))
        chroma_stft_10.append(np.mean(chst[9]))
        chroma_stft_11.append(np.mean(chst[10]))
        chroma_stft_12.append(np.mean(chst[11]))
        rmse.append(np.mean(librosa.feature.rms(y=y)))
        spec_cent.append(np.mean(librosa.feature.spectral_centroid(y=y, sr=sr)))
        spec_bw.append(np.mean(librosa.feature.spectral_bandwidth(y=y, sr=sr)))
        spec_cont.append(np.mean(librosa.feature.spectral_contrast(y=y, sr=sr)))
        spec_flat.append(np.mean(librosa.feature.spectral_flatness(y=y)))
        rolloff.append(np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr)))
        ton=librosa.feature.tonnetz(y=y, sr=sr)
        tonnetz_1.append(np.mean(ton[0]))
        tonnetz_2.append(np.mean(ton[1]))
        tonnetz_3.append(np.mean(ton[2]))
        tonnetz_4.append(np.mean(ton[3]))
        tonnetz_5.append(np.mean(ton[4]))
        tonnetz_6.append(np.mean(ton[5]))
        zcr.append(np.mean(librosa.feature.zero_crossing_rate(y)))
        songnames.append(int(os.path.splitext(os.path.basename(filename))[0]))
        mfcc=librosa.feature.mfcc(y=y, sr=sr)
        mfcc1.append(np.mean(mfcc[0]))
        mfcc2.append(np.mean(mfcc[1]))
        mfcc3.append(np.mean(mfcc[2]))
        mfcc4.append(np.mean(mfcc[3]))
        mfcc5.append(np.mean(mfcc[4]))
        mfcc6.append(np.mean(mfcc[5]))
        mfcc7.append(np.mean(mfcc[6]))
        mfcc8.append(np.mean(mfcc[7]))
        mfcc9.append(np.mean(mfcc[8]))
        mfcc10.append(np.mean(mfcc[9]))
        mfcc11.append(np.mean(mfcc[10]))
        mfcc12.append(np.mean(mfcc[11]))
        mfcc13.append(np.mean(mfcc[12]))
        mfcc14.append(np.mean(mfcc[13]))
        mfcc15.append(np.mean(mfcc[14]))
        mfcc16.append(np.mean(mfcc[15]))
        mfcc17.append(np.mean(mfcc[16]))
        mfcc18.append(np.mean(mfcc[17]))
        mfcc19.append(np.mean(mfcc[18]))
        mfcc20.append(np.mean(mfcc[19]))
        id.append(count)
        count += 1

# %%
df=pd.DataFrame(data)
df=df.sort_values(by=['songname'], axis=0)
df.head()
# Out:
#         id  songname       tempo  chroma_shft_1  chroma_shft_2  chroma_shft_3  \
# 1099  1100         2  143.554688       0.232202       0.201824       0.222168
# 1246  1247         3   95.703125       0.437333       0.364443       0.396659
# 1339  1340         4  172.265625       0.276094       0.208899       0.237324
# 1425  1426         5   99.384014       0.252043       0.334039       0.275257
# 1572  1573         7  117.453835       0.335063       0.277743       0.340410
#
#       chroma_shft_4  chroma_shft_5  chroma_shft_6  chroma_shft_7  ...  \
# 1099       0.307799       0.472035       0.495194       0.343369  ...
# 1246       0.466947       0.577430       0.489825       0.402038  ...
# 1339       0.251551       0.484929       0.253767       0.190352  ...
# 1425       0.431722       0.289240       0.228196       0.425863  ...
# 1572       0.380032       0.427186       0.445793       0.377289  ...
#
#         mfcc11    mfcc12     mfcc13    mfcc14     mfcc15     mfcc16  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1802 entries, 1099 to 1164
# Data columns (total 48 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              1802 non-null   int64
#  1   songname        1802 non-null   int64
#  2   tempo           1802 non-null   float64
#  3   chroma_shft_1   1802 non-null   float64
#  4   chroma_shft_2   1802 non-null   float64
#  5   chroma_shft_3   1802 non-null   float64
#  6   chroma_shft_4   1802 non-null   float64
#  7   chroma_shft_5   1802 non-null   float64
#  8   chroma_shft_6   1802 non-null   float64
#  9   chroma_shft_7   1802 non-null   float64
#  10  chroma_shft_8   1802 non-null   float64
#  11  chroma_shft_9   1802 non-null   float64
#  12  chroma_shft_10  1802 non-null   float64
#  13  chroma_shft_11  1802 non-null   float64
#  14  chroma_shft_12  1802 non-null   float64
#  15  rmse            1802 non-null   float64
# ...

# %%
df.to_csv("data.csv", mode='w')

# %%
df1 = pd.read_csv('data.csv')

# %%
df1.head(10)
# Out:
#    Unnamed: 0    id  songname       tempo  chroma_shft_1  chroma_shft_2  \
# 0        1099  1100         2  143.554688       0.232202       0.201824
# 1        1246  1247         3   95.703125       0.437333       0.364443
# 2        1339  1340         4  172.265625       0.276094       0.208899
# 3        1425  1426         5   99.384014       0.252043       0.334039
# 4        1572  1573         7  117.453835       0.335063       0.277743
# 5        1656  1657         8  161.499023       0.350905       0.293683
# 6           0     1        10   95.703125       0.309709       0.286007
# 7         220   221        12  129.199219       0.548154       0.366429
# 8         331   332        13   86.132812       0.425267       0.302434
# 9         767   768        17  107.666016       0.346668       0.329112
#
#    chroma_shft_3  chroma_shft_4  chroma_shft_5  chroma_shft_6  ...     mfcc11  \
# 0       0.222168       0.307799       0.472035       0.495194  ...  -5.725076
# ...

# %%
df2 = pd.read_csv('./song_level/static_annotations_averaged_songs_1_2000.csv')
df3 = pd.read_csv('./song_level/static_annotations_averaged_songs_2000_2058.csv')
y=pd.concat([df2,df3])

# %%
y.columns
# Out:
# Index(['song_id', ' valence_mean', ' valence_std', ' arousal_mean',
#        ' arousal_std', ' valence_ max_mean', ' valence_max_std',
#        ' valence_min_mean', ' valence_min_std', ' arousal_max_mean',
#        ' arousal_max_std', ' arousal_min_mean', ' arousal_min_std'],
#       dtype='object')

# %%
y.drop([' valence_ max_mean'], axis='columns', inplace=True)

# %%
y.drop([' valence_max_std',' valence_min_mean', ' valence_min_std', ' arousal_max_mean',
       ' arousal_max_std', ' arousal_min_mean', ' arousal_min_std'], axis='columns', inplace=True)

# %%
y.drop(['song_id', ' valence_std',' arousal_std'], axis='columns', inplace=True)

# %%
y
# Out:
#      valence_mean   arousal_mean
# 0            3.10           3.00
# 1            3.50           3.30
# 2            5.70           5.50
# 3            4.40           5.30
# 4            5.80           6.40
# ..            ...            ...
# 53           5.40           3.60
# 54           5.00           5.20
# 55           5.00           4.60
# 56           3.17           6.83
# 57           3.80           5.80
#
# [1802 rows x 2 columns]

# %%
df1.drop('songname', axis=1, inplace=True)
df1.drop('Unnamed: 0', axis=1, inplace=True)
df1.drop('id', axis=1, inplace=True)

# %%
#arousal 입력 데이터
x_data2=df1.iloc[:,[0,13,14,15,16,17,18,25]]

# %%
x_data2
# Out:
#            tempo      rmse    spec_cent      spec_bw  spec_cont  spec_flat  \
# 0     143.554688  0.105888  1789.152236  2104.961488  21.258568   0.008221
# 1      95.703125  0.116918   958.364724  1660.823035  22.891666   0.002434
# 2     172.265625  0.187612  1661.804757  2064.728795  22.020823   0.007386
# 3      99.384014  0.150458  1599.806604  2083.374812  24.130002   0.005222
# 4     117.453835  0.269291  1255.913592  2074.011971  19.806196   0.003186
# ...          ...       ...          ...          ...        ...        ...
# 1797  184.570312  0.113914   592.669290   932.052333  26.638011   0.000286
# 1798  123.046875  0.163434  2645.990657  2483.160600  22.317470   0.023953
# 1799   99.384014  0.083154  1500.450778  1863.403171  20.468362   0.006594
# 1800  123.046875  0.175876  2359.897098  2433.237479  20.788242   0.021312
# 1801  112.347147  0.138630  1775.542773  1963.678673  22.851506   0.009543
#
#           rolloff       zcr
# 0     3775.948677  0.067953
# ...

# %%
df1
# Out:
#            tempo  chroma_shft_1  chroma_shft_2  chroma_shft_3  chroma_shft_4  \
# 0     143.554688       0.232202       0.201824       0.222168       0.307799
# 1      95.703125       0.437333       0.364443       0.396659       0.466947
# 2     172.265625       0.276094       0.208899       0.237324       0.251551
# 3      99.384014       0.252043       0.334039       0.275257       0.431722
# 4     117.453835       0.335063       0.277743       0.340410       0.380032
# ...          ...            ...            ...            ...            ...
# 1797  184.570312       0.349507       0.176518       0.250288       0.222301
# 1798  123.046875       0.367672       0.355572       0.475085       0.305545
# 1799   99.384014       0.307433       0.293780       0.425214       0.443325
# 1800  123.046875       0.380303       0.354667       0.342455       0.293341
# 1801  112.347147       0.273126       0.258797       0.345431       0.324426
#
# ...

# %%
import tensorflow as tf
import numpy as np

# %%
#arousal값
y_data1=y[[' arousal_mean']]

# %%
y_data1
# Out:
#      arousal_mean
# 0            3.00
# 1            3.30
# 2            5.50
# 3            5.30
# 4            6.40
# ..            ...
# 53           3.60
# 54           5.20
# 55           4.60
# 56           6.83
# 57           5.80
#
# [1802 rows x 1 columns]

# %%
#valence값
y_data2=y[[' valence_mean']]
y_data2
# Out:
#      valence_mean
# 0            3.10
# 1            3.50
# 2            5.70
# 3            4.40
# 4            5.80
# ..            ...
# 53           5.40
# 54           5.00
# 55           5.00
# 56           3.17
# 57           3.80
#
# [1802 rows x 1 columns]

# %%
x_data=df1

# %%
x_data
# Out:
#            tempo  chroma_shft_1  chroma_shft_2  chroma_shft_3  chroma_shft_4  \
# 0     143.554688       0.232202       0.201824       0.222168       0.307799
# 1      95.703125       0.437333       0.364443       0.396659       0.466947
# 2     172.265625       0.276094       0.208899       0.237324       0.251551
# 3      99.384014       0.252043       0.334039       0.275257       0.431722
# 4     117.453835       0.335063       0.277743       0.340410       0.380032
# ...          ...            ...            ...            ...            ...
# 1797  184.570312       0.349507       0.176518       0.250288       0.222301
# 1798  123.046875       0.367672       0.355572       0.475085       0.305545
# 1799   99.384014       0.307433       0.293780       0.425214       0.443325
# 1800  123.046875       0.380303       0.354667       0.342455       0.293341
# 1801  112.347147       0.273126       0.258797       0.345431       0.324426
#
# ...

# %%
#Arousal에 대한 훈련과 테스트 데이터 분리
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_data2,y_data1, test_size=0.2, random_state=0)

# %%
#rmsle구하는 함수
from sklearn.metrics import mean_squared_error
def rmsle(y, y_pred): 
    return np.sqrt(mean_squared_error(y, y_pred))

# %%
#랜덤포레스트(Arousal)
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor(random_state=42,max_depth=10,n_estimators=100)
model_rf.fit(x_train, y_train)
train_pred_rf =model_rf.predict(x_train)
test_pred_rf = model_rf.predict(x_test)
print(model_rf.score(x_train, y_train))
print(model_rf.score(x_test, y_test))
print(rmsle(y_train, train_pred_rf))
print(rmsle(y_test, test_pred_rf))
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# 0.8242545867335772
# 0.42665622656753766
# 0.5391509254339317
# 0.9575003985009175

# %%
#XGBRegressor(Arousal)
from xgboost import XGBRegressor
model_xgb = XGBRegressor(learning_rate=0.1,
                             max_depth=5,
                             n_estimators=100,n_jobs=12)
model_xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.1, max_delta_step=0, max_depth=5,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=12, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
train_pred_1 =model_xgb.predict(x_train)
test_pred_1 = model_xgb.predict(x_test)
print(model_xgb.score(x_train,y_train))
print(model_xgb.score(x_test, y_test))
print(rmsle(y_train, train_pred_1))
print(rmsle(y_test, test_pred_1))
# Out:
# 0.8240411343190389
# 0.37372613060334425
# 0.5394782402190836
# 1.0007222569780443

# %%
#Valence에 대한 훈련과 테스트 데이터 분리
x_train_2, x_test_2, y_train_2, y_test_2 = train_test_split(x_data,y_data2, test_size=0.2, random_state=0)

# %%
#랜덤포레스트(Valence)
model_rf_2 = RandomForestRegressor(random_state=42, n_estimators=100)
model_rf_2.fit(x_train_2, y_train_2)
train_pred_rf_2 =model_rf_2.predict(x_train_2)
test_pred_rf_2 = model_rf_2.predict(x_test_2)
print(model_rf_2.score(x_train_2, y_train_2))
print(model_rf_2.score(x_test_2, y_test_2))
print(rmsle(y_train_2, train_pred_rf_2))
print(rmsle(y_test_2, test_pred_rf_2))
# Out:
# C:\anaconda\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# 0.9187179742493498
# 0.4465508469555901
# 0.3376494234726439
# 0.841714037510263

# %%
#XGBRegressor(Valence)
from xgboost import XGBRegressor
model_xgb_2 = XGBRegressor(learning_rate=0.01,
                             max_depth=10,
                             n_estimators=1000,n_jobs=12)
model_xgb_2.fit(x_train_2,y_train_2)
# Out:
# XGBRegressor(base_score=0.5, booster=None, colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints=None,
#              learning_rate=0.01, max_delta_step=0, max_depth=10,
#              min_child_weight=1, missing=nan, monotone_constraints=None,
#              n_estimators=1000, n_jobs=12, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#              validate_parameters=False, verbosity=None)

# %%
train_pred_2 =model_xgb_2.predict(x_train_2)
test_pred_2 = model_xgb_2.predict(x_test_2)
print(model_xgb_2.score(x_train_2,y_train_2))
print(model_xgb_2.score(x_test_2, y_test_2))
print(rmsle(y_train_2, train_pred_2))
print(rmsle(y_test_2, test_pred_2))
# Out:
# 0.9999116253798944
# 0.40090787132050987
# 0.011133521011729803
# 0.8757346088546006

# %%
import seaborn as sns
# Basic Scatter Plot

sns.regplot(y_test_2, 

           y_test, 

           fit_reg=False) # no regression line
plt.xlabel('test_valence', fontsize=14)

plt.ylabel('test_arousal', fontsize=14)

plt.show()

# %%
import seaborn as sns
# Basic Scatter Plot

sns.regplot(test_pred_rf_2
            ,test_pred_rf,  

           fit_reg=False) # no regression line
plt.xlabel('y_test_v', fontsize=14)

plt.ylabel('test_pred_a', fontsize=14)

plt.show()

# %%
df4 = pd.read_csv('data_music.csv')

# %%
df4
# Out:
#      Unnamed: 0   id                                           songname  \
# 0             0    1  01. 가슴이 시린 게 (My Heartstore) - Lee Hyun 이현 (8e...
# 1             1    2                           ABTB - Free Rider (무임승차)
# 2             4    5               AOA - 심쿵해 (Heart Attack) Music Video
# 3             2    3    Adele - Someone Like You (Official Music Video)
# 4             3    4                            And Now The Day Is Done
# ..          ...  ...                                                ...
# 156         156  157      하현우 (국카스텐) - DARKNESS [메이플스토리 MapleStory OST]
# 157         157  158  하현우 - 돌덩이 (이태원 클라쓰 OST PART.03)   가사 ITAEWON C...
# 158         158  159                                  한희정-더이상슬픔을노래하지않으리
# 159         159  160                                         황인욱-Phocha
# 160         160  161  휘성 (Whee Sung) - 결혼까지 생각했어 (Even thought of ma...
#
#           tempo  chroma_shft_1  chroma_shft_2  chroma_shft_3  chroma_shft_4  \
# ...

# %%
df5=df4['songname']

# %%
df4.drop('songname', axis=1, inplace=True)
df4.drop('Unnamed: 0', axis=1, inplace=True)
df4.drop('id', axis=1, inplace=True)
df6=df4.iloc[:,[0,13,14,15,16,17,18,25]]

# %%
pred_1 = model_xgb.predict(df6)
pred_2 = model_xgb_2.predict(df4)

# %%
pred_1_rf = model_rf.predict(df6)
pred_2_rf = model_rf_2.predict(df4)

# %%
df4 = pd.DataFrame({"songname":df5 ,"arousal":pred_1.round(2), "valence": pred_2.round(2)})
df7 = pd.DataFrame({"songname":df5 ,"arousal":pred_1_rf.round(2), "valence": pred_2_rf.round(2)})

# %%
df7
# Out:
#                                               songname  arousal  valence
# 0    01. 가슴이 시린 게 (My Heartstore) - Lee Hyun 이현 (8e...     5.49     5.23
# 1                             ABTB - Free Rider (무임승차)     5.80     6.79
# 2                 AOA - 심쿵해 (Heart Attack) Music Video     5.91     6.86
# 3      Adele - Someone Like You (Official Music Video)     5.26     5.07
# 4                              And Now The Day Is Done     5.36     4.07
# ..                                                 ...      ...      ...
# 156      하현우 (국카스텐) - DARKNESS [메이플스토리 MapleStory OST]     5.79     6.56
# 157  하현우 - 돌덩이 (이태원 클라쓰 OST PART.03)   가사 ITAEWON C...     5.96     5.89
# 158                                  한희정-더이상슬픔을노래하지않으리     4.53     4.89
# 159                                         황인욱-Phocha     5.82     5.33
# 160  휘성 (Whee Sung) - 결혼까지 생각했어 (Even thought of ma...     5.65     6.63
#
# [161 rows x 3 columns]

# %%
import seaborn as sns
# Basic Scatter Plot

sns.regplot(pred_1_rf, 

           pred_2_rf, 

           fit_reg=False) # no regression line
plt.xlabel('y_test_v', fontsize=14)

plt.ylabel('test_pred', fontsize=14)

plt.show()

# %%
df7.to_csv("music.csv", mode='w')
